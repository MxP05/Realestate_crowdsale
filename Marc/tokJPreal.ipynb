# %%
import pandas as pd
from pathlib import Path
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
read_file = pd.read_csv(Path('../desktop/13.csv'))
read_file
# Out:
#             No                                 Type  \
# 0            1         Pre-owned Condominiums, etc.
# 1            2         Pre-owned Condominiums, etc.
# 2            3  Residential Land(Land and Building)
# 3            4  Residential Land(Land and Building)
# 4            5         Pre-owned Condominiums, etc.
# ...        ...                                  ...
# 406570  406571          Residential Land(Land Only)
# 406571  406572          Residential Land(Land Only)
# 406572  406573          Residential Land(Land Only)
# 406573  406574          Residential Land(Land Only)
# 406574  406575  Residential Land(Land and Building)
#
#                             Region  MunicipalityCode Prefecture  \
# 0                              NaN             13101      Tokyo
# 1                              NaN             13101      Tokyo
# 2                  Commercial Area             13101      Tokyo
# 3                  Commercial Area             13101      Tokyo
# ...

# %%
#get the price of column file
price = read_file['TradePrice']
#show 100 rows
price.head(100)
#convert price from japanese yen to usd
price_usd = price * 0.0091

# %%
price_usd.head(100)
# Out:
# 0       364000.0
# 1      1183000.0
# 2      3640000.0
# 3      1638000.0
# 4       910000.0
#          ...
# 95    14560000.0
# 96      473200.0
# 97      273000.0
# 98     1638000.0
# 99      300300.0
# Name: TradePrice, Length: 100, dtype: float64

# %%
#concatenate the price_usd column to the read_file
read_file['TradePriceUSD'] = price_usd

# %%
read_file
# Out:
#             No                                 Type  \
# 0            1         Pre-owned Condominiums, etc.
# 1            2         Pre-owned Condominiums, etc.
# 2            3  Residential Land(Land and Building)
# 3            4  Residential Land(Land and Building)
# 4            5         Pre-owned Condominiums, etc.
# ...        ...                                  ...
# 406570  406571          Residential Land(Land Only)
# 406571  406572          Residential Land(Land Only)
# 406572  406573          Residential Land(Land Only)
# 406573  406574          Residential Land(Land Only)
# 406574  406575  Residential Land(Land and Building)
#
#                             Region  MunicipalityCode Prefecture  \
# 0                              NaN             13101      Tokyo
# 1                              NaN             13101      Tokyo
# 2                  Commercial Area             13101      Tokyo
# 3                  Commercial Area             13101      Tokyo
# ...

# %%
read_file.rename(columns={'TradePrice':'TradePriceJPY'}, inplace=True)

# %%
read_file
# Out:
#             No                                 Type  \
# 0            1         Pre-owned Condominiums, etc.
# 1            2         Pre-owned Condominiums, etc.
# 2            3  Residential Land(Land and Building)
# 3            4  Residential Land(Land and Building)
# 4            5         Pre-owned Condominiums, etc.
# ...        ...                                  ...
# 406570  406571          Residential Land(Land Only)
# 406571  406572          Residential Land(Land Only)
# 406572  406573          Residential Land(Land Only)
# 406573  406574          Residential Land(Land Only)
# 406574  406575  Residential Land(Land and Building)
#
#                             Region  MunicipalityCode Prefecture  \
# 0                              NaN             13101      Tokyo
# 1                              NaN             13101      Tokyo
# 2                  Commercial Area             13101      Tokyo
# 3                  Commercial Area             13101      Tokyo
# ...
